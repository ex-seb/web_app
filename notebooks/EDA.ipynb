# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv("metro.csv")
df.info()
df.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17550 entries, 0 to 17549
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   fecha           17550 non-null  object
#  1   mes             17550 non-null  object
#  2   anio            17550 non-null  int64
#  3   linea           17550 non-null  object
#  4   estacion        17550 non-null  object
#  5   tipo_pago       17550 non-null  object
#  6   afluencia       17550 non-null  int64
#  7   temporal_fecha  17550 non-null  object
#  8   ..anio_fecha    17550 non-null  int64
# dtypes: int64(3), object(6)
# memory usage: 1.2+ MB
#             fecha    mes  anio     linea          estacion  tipo_pago  \
# 12916  2024-06-23  Junio  2024   Linea 1           Sevilla    Prepago
# 8174   2024-06-14  Junio  2024  Linea 12       Eje Central  Gratuidad
# 4169   2024-06-08  Junio  2024   Linea 2           Popotla  Gratuidad
# 16784  2024-06-29  Junio  2024   Linea 9  Ciudad Deportiva  Gratuidad
# 11054  2024-06-19  Junio  2024   Linea B     Ciudad Azteca  Gratuidad
# 17045  2024-06-30  Junio  2024   Linea 2            Normal  Gratuidad
# 4525   2024-06-08  Junio  2024   Linea 9          Tacubaya    Prepago
# 7138   2024-06-13  Junio  2024   Linea 2         Nativitas    Prepago
# 15411  2024-06-27  Junio  2024   Linea 4     Fray Servando     Boleto
# 2216   2024-06-04  Junio  2024   Linea A            La Paz  Gratuidad
#
#        afluencia temporal_fecha  ..anio_fecha
# 12916          0        2024-06          2024
# 8174        1426        2024-06          2024
# 4169        1116        2024-06          2024
# 16784          0        2024-06          2024
# 11054       6758        2024-06          2024
# 17045       1748        2024-06          2024
# 4525       48000        2024-06          2024
# 7138       15459        2024-06          2024
# 15411          0        2024-06          2024
# 2216        5247        2024-06          2024

# %%
linea_a = df[df['linea'].str.contains('Linea A')]
linea_a.head()
# Out:
#           fecha    mes  anio    linea           estacion  tipo_pago  \
# 432  2024-06-01  Junio  2024  Linea A          Pantitlán     Boleto
# 433  2024-06-01  Junio  2024  Linea A          Pantitlán    Prepago
# 434  2024-06-01  Junio  2024  Linea A          Pantitlán  Gratuidad
# 435  2024-06-01  Junio  2024  Linea A  Agrícola Oriental     Boleto
# 436  2024-06-01  Junio  2024  Linea A  Agrícola Oriental    Prepago
#
#      afluencia temporal_fecha  ..anio_fecha
# 432          0        2024-06          2024
# 433      13939        2024-06          2024
# 434       3513        2024-06          2024
# 435          0        2024-06          2024
# 436       7729        2024-06          2024

# %%
fig = px.histogram(linea_a, x="estacion", y='afluencia',
                   labels={
                       "estacion": "Estación",
                       "afluencia": "Afluencia"
                   }, title="Afluencia por estación")
fig.show()

# %%
fig = px.scatter(linea_a, x="estacion", y="afluencia", color="tipo_pago",
                 labels={"estacion": "Estación",
                         "afluencia": "Afluencia",
                         "tipo_pago": "Tipo de Pago"},
                         title="Tipo de pago por estación")
fig.show()

# %%
fig = px.bar(linea_a, x="estacion", y="afluencia", color="tipo_pago",
                 labels={"estacion": "Estación",
                         "afluencia": "Afluencia",
                         "tipo_pago": "Tipo de Pago"},
                 title="Tipo de pago por estación")
fig.show()

# %%
linea_1 = df[df['linea'] =='Linea 1']
linea_1.head()
# Out:
#         fecha    mes  anio    linea   estacion  tipo_pago  afluencia  \
# 0  2024-06-01  Junio  2024  Linea 1  Pantitlán     Boleto          0
# 1  2024-06-01  Junio  2024  Linea 1  Pantitlán    Prepago      21984
# 2  2024-06-01  Junio  2024  Linea 1  Pantitlán  Gratuidad       3112
# 3  2024-06-01  Junio  2024  Linea 1   Zaragoza     Boleto          0
# 4  2024-06-01  Junio  2024  Linea 1   Zaragoza    Prepago      14523
#
#   temporal_fecha  ..anio_fecha
# 0        2024-06          2024
# 1        2024-06          2024
# 2        2024-06          2024
# 3        2024-06          2024
# 4        2024-06          2024

# %%
fig = px.bar(linea_1, x="estacion", y="afluencia", color="tipo_pago",
                 labels={"estacion": "Estación",
                         "afluencia": "Afluencia",
                         "tipo_pago": "Tipo de Pago"},
                 title="Tipo de pago por estación")
fig.show()

# %%
linea_2 = df[df['linea'] =='Linea 2']
linea_2.head()
# Out:
#          fecha    mes  anio    linea        estacion  tipo_pago  afluencia  \
# 60  2024-06-01  Junio  2024  Linea 2  Cuatro Caminos     Boleto          0
# 61  2024-06-01  Junio  2024  Linea 2  Cuatro Caminos    Prepago      85574
# 62  2024-06-01  Junio  2024  Linea 2  Cuatro Caminos  Gratuidad       9133
# 63  2024-06-01  Junio  2024  Linea 2       Panteones     Boleto          0
# 64  2024-06-01  Junio  2024  Linea 2       Panteones    Prepago       7957
#
#    temporal_fecha  ..anio_fecha
# 60        2024-06          2024
# 61        2024-06          2024
# 62        2024-06          2024
# 63        2024-06          2024
# 64        2024-06          2024

# %%
fig = px.bar(linea_2, x="estacion", y="afluencia", color="tipo_pago",
                 labels={"estacion": "Estación",
                         "afluencia": "Afluencia",
                         "tipo_pago": "Tipo de Pago"},
                 title="Tipo de pago por estación")
fig.show()

# %%
linea_3 = df[df['linea'] =='Linea 3']
linea_3.head()
# Out:
#           fecha    mes  anio    linea               estacion  tipo_pago  \
# 132  2024-06-01  Junio  2024  Linea 3          Indios Verdes     Boleto
# 133  2024-06-01  Junio  2024  Linea 3          Indios Verdes    Prepago
# 134  2024-06-01  Junio  2024  Linea 3          Indios Verdes  Gratuidad
# 135  2024-06-01  Junio  2024  Linea 3  Deportivo 18 de Marzo     Boleto
# 136  2024-06-01  Junio  2024  Linea 3  Deportivo 18 de Marzo    Prepago
#
#      afluencia temporal_fecha  ..anio_fecha
# 132          0        2024-06          2024
# 133      71781        2024-06          2024
# 134       5601        2024-06          2024
# 135          0        2024-06          2024
# 136      17718        2024-06          2024

# %%
fig = px.bar(linea_3, x="estacion", y="afluencia", color="tipo_pago",
                 labels={"estacion": "Estación",
                         "afluencia": "Afluencia",
                         "tipo_pago": "Tipo de Pago"},
                 title="Tipo de pago por estación")
fig.show()

# %%
linea_4 = df[df['linea'] =='Linea 4']
linea_4.head()
# Out:
#           fecha    mes  anio    linea     estacion  tipo_pago  afluencia  \
# 195  2024-06-01  Junio  2024  Linea 4  Santa Anita     Boleto          0
# 196  2024-06-01  Junio  2024  Linea 4  Santa Anita    Prepago       1633
# 197  2024-06-01  Junio  2024  Linea 4  Santa Anita  Gratuidad        390
# 198  2024-06-01  Junio  2024  Linea 4      Jamaica     Boleto          0
# 199  2024-06-01  Junio  2024  Linea 4      Jamaica    Prepago       4299
#
#     temporal_fecha  ..anio_fecha
# 195        2024-06          2024
# 196        2024-06          2024
# 197        2024-06          2024
# 198        2024-06          2024
# 199        2024-06          2024

# %%
fig = px.bar(linea_4, x="estacion", y="afluencia", color="tipo_pago",
                 labels={"estacion": "Estación",
                         "afluencia": "Afluencia",
                         "tipo_pago": "Tipo de Pago"},
                 title="Tipo de pago por estación")
fig.show()

# %%
linea_5 = df[df['linea'] =='Linea 5']
linea_5.head()
# Out:
#           fecha    mes  anio    linea                estacion  tipo_pago  \
# 225  2024-06-01  Junio  2024  Linea 5             Politécnico     Boleto
# 226  2024-06-01  Junio  2024  Linea 5             Politécnico    Prepago
# 227  2024-06-01  Junio  2024  Linea 5             Politécnico  Gratuidad
# 228  2024-06-01  Junio  2024  Linea 5  Instituto del Petróleo     Boleto
# 229  2024-06-01  Junio  2024  Linea 5  Instituto del Petróleo    Prepago
#
#      afluencia temporal_fecha  ..anio_fecha
# 225          0        2024-06          2024
# 226      15262        2024-06          2024
# 227       2026        2024-06          2024
# 228          0        2024-06          2024
# 229       2708        2024-06          2024

# %%
fig = px.bar(linea_5, x="estacion", y="afluencia", color="tipo_pago",
                 labels={"estacion": "Estación",
                         "afluencia": "Afluencia",
                         "tipo_pago": "Tipo de Pago"},
                 title="Tipo de pago por estación")
fig.show()

# %%
linea_6 = df[df['linea'] =='Linea 6']
linea_6.head()
# Out:
#           fecha    mes  anio    linea    estacion  tipo_pago  afluencia  \
# 264  2024-06-01  Junio  2024  Linea 6  El Rosario     Boleto          0
# 265  2024-06-01  Junio  2024  Linea 6  El Rosario    Prepago       9454
# 266  2024-06-01  Junio  2024  Linea 6  El Rosario  Gratuidad       1309
# 267  2024-06-01  Junio  2024  Linea 6   Tezozómoc     Boleto          0
# 268  2024-06-01  Junio  2024  Linea 6   Tezozómoc    Prepago       3715
#
#     temporal_fecha  ..anio_fecha
# 264        2024-06          2024
# 265        2024-06          2024
# 266        2024-06          2024
# 267        2024-06          2024
# 268        2024-06          2024

# %%
fig = px.bar(linea_6, x="estacion", y="afluencia", color="tipo_pago",
                 labels={"estacion": "Estación",
                         "afluencia": "Afluencia",
                         "tipo_pago": "Tipo de Pago"},
                 title="Tipo de pago por estación")
fig.show()

# %%
linea_7 = df[df['linea'] =='Linea 7']
linea_7.head()
# Out:
#           fecha    mes  anio    linea        estacion  tipo_pago  afluencia  \
# 297  2024-06-01  Junio  2024  Linea 7      El Rosario     Boleto          0
# 298  2024-06-01  Junio  2024  Linea 7      El Rosario    Prepago      17713
# 299  2024-06-01  Junio  2024  Linea 7      El Rosario  Gratuidad       2326
# 300  2024-06-01  Junio  2024  Linea 7  Aquiles Serdán     Boleto          0
# 301  2024-06-01  Junio  2024  Linea 7  Aquiles Serdán    Prepago       7404
#
#     temporal_fecha  ..anio_fecha
# 297        2024-06          2024
# 298        2024-06          2024
# 299        2024-06          2024
# 300        2024-06          2024
# 301        2024-06          2024

# %%
fig = px.bar(linea_7, x="estacion", y="afluencia", color="tipo_pago",
                 labels={"estacion": "Estación",
                         "afluencia": "Afluencia",
                         "tipo_pago": "Tipo de Pago"},
                 title="Tipo de pago por estación")
fig.show()

# %%
linea_8 = df[df['linea'] =='Linea 8']
linea_8.head()
# Out:
#           fecha    mes  anio    linea             estacion  tipo_pago  \
# 339  2024-06-01  Junio  2024  Linea 8  Garibaldi/Lagunilla     Boleto
# 340  2024-06-01  Junio  2024  Linea 8  Garibaldi/Lagunilla    Prepago
# 341  2024-06-01  Junio  2024  Linea 8  Garibaldi/Lagunilla  Gratuidad
# 342  2024-06-01  Junio  2024  Linea 8         Bellas Artes     Boleto
# 343  2024-06-01  Junio  2024  Linea 8         Bellas Artes    Prepago
#
#      afluencia temporal_fecha  ..anio_fecha
# 339          0        2024-06          2024
# 340      15262        2024-06          2024
# 341       2565        2024-06          2024
# 342          0        2024-06          2024
# 343      18281        2024-06          2024

# %%
fig = px.bar(linea_8, x="estacion", y="afluencia", color="tipo_pago",
                 labels={"estacion": "Estación",
                         "afluencia": "Afluencia",
                         "tipo_pago": "Tipo de Pago"},
                 title="Tipo de pago por estación")
fig.show()

# %%
linea_9 = df[df['linea'] =='Linea 9']
linea_9.head()
# Out:
#           fecha    mes  anio    linea   estacion  tipo_pago  afluencia  \
# 396  2024-06-01  Junio  2024  Linea 9  Pantitlán     Boleto          0
# 397  2024-06-01  Junio  2024  Linea 9  Pantitlán    Prepago          0
# 398  2024-06-01  Junio  2024  Linea 9  Pantitlán  Gratuidad          0
# 399  2024-06-01  Junio  2024  Linea 9     Puebla     Boleto          0
# 400  2024-06-01  Junio  2024  Linea 9     Puebla    Prepago          0
#
#     temporal_fecha  ..anio_fecha
# 396        2024-06          2024
# 397        2024-06          2024
# 398        2024-06          2024
# 399        2024-06          2024
# 400        2024-06          2024

# %%
fig = px.bar(linea_9, x="estacion", y="afluencia", color="tipo_pago",
                 labels={"estacion": "Estación",
                         "afluencia": "Afluencia",
                         "tipo_pago": "Tipo de Pago"},
                 title="Tipo de pago por estación")
fig.show()

# %%
linea_b = df[df['linea'] =='Linea B']
linea_b.head()
# Out:
#           fecha    mes  anio    linea    estacion  tipo_pago  afluencia  \
# 462  2024-06-01  Junio  2024  Linea B  Buenavista     Boleto          0
# 463  2024-06-01  Junio  2024  Linea B  Buenavista    Prepago      44530
# 464  2024-06-01  Junio  2024  Linea B  Buenavista  Gratuidad       3487
# 465  2024-06-01  Junio  2024  Linea B    Guerrero     Boleto          0
# 466  2024-06-01  Junio  2024  Linea B    Guerrero    Prepago       5626
#
#     temporal_fecha  ..anio_fecha
# 462        2024-06          2024
# 463        2024-06          2024
# 464        2024-06          2024
# 465        2024-06          2024
# 466        2024-06          2024

# %%
fig = px.bar(linea_b, x="estacion", y="afluencia", color="tipo_pago",
                 labels={"estacion": "Estación",
                         "afluencia": "Afluencia",
                         "tipo_pago": "Tipo de Pago"},
                 title="Tipo de pago por estación")
fig.show()

# %%
linea_12 = df[df['linea'] =='Linea 12']
linea_12.head()
# Out:
#           fecha    mes  anio     linea   estacion  tipo_pago  afluencia  \
# 525  2024-06-01  Junio  2024  Linea 12    Tláhuac     Boleto          0
# 526  2024-06-01  Junio  2024  Linea 12    Tláhuac    Prepago      32408
# 527  2024-06-01  Junio  2024  Linea 12    Tláhuac  Gratuidad       3850
# 528  2024-06-01  Junio  2024  Linea 12  Tlaltenco     Boleto          0
# 529  2024-06-01  Junio  2024  Linea 12  Tlaltenco    Prepago       3282
#
#     temporal_fecha  ..anio_fecha
# 525        2024-06          2024
# 526        2024-06          2024
# 527        2024-06          2024
# 528        2024-06          2024
# 529        2024-06          2024

# %%
fig = px.bar(linea_12, x="estacion", y="afluencia", color="tipo_pago",
                 labels={"estacion": "Estación",
                         "afluencia": "Afluencia",
                         "tipo_pago": "Tipo de Pago"},
                 title="Tipo de pago por estación")
fig.show()
